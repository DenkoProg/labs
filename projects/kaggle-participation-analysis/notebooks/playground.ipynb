# %%
import pandas as pd

# %%
for csv in ["users.csv", "competitions.csv", "submissions.csv", "teams.csv", "teammemberships.csv"]:
    df = pd.read_csv(
        f"/Users/denys.koval/Labs/projects/kaggle_participation_analysis/data/{csv}"
    )
    print(f"File: {csv}")
    df.info()
# Out:
# File: users.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24156872 entries, 0 to 24156871
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Id                     int64
#  1   UserName               object
#  2   DisplayName            object
#  3   RegisterDate           object
#  4   PerformanceTier        int64
#  5   Country                object
#  6   LocationSharingOptOut  bool
# dtypes: bool(1), int64(2), object(4)
# memory usage: 1.1+ GB
# File: competitions.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9590 entries, 0 to 9589
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Id                                9590 non-null   int64
#  1   Slug                              9590 non-null   object
#  2   Title                             9590 non-null   object
# ...
